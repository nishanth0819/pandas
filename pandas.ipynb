# %%
import pandas as pd
df=pd.read_csv("Desktop/data/data.csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
rows,clo=df.shape

# %%
rows
# Out:
# 169

# %%
df.head(19)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112       NaN
# 18        60    103       123     323.0

# %%
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df[2:5]
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df[:]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df.Duration
# Out:
# 0      60
# 1      60
# 2      60
# 3      45
# 4      45
#        ..
# 164    60
# 165    60
# 166    60
# 167    75
# 168    75
# Name: Duration, Length: 169, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Duration','Pulse']]
# Out:
#      Duration  Pulse
# 0          60    110
# 1          60    117
# 2          60    103
# 3          45    109
# 4          45    117
# ..        ...    ...
# 164        60    105
# 165        60    110
# 166        60    115
# 167        75    120
# 168        75    125
#
# [169 rows x 2 columns]

# %%
df['Duration'].max()
# Out:
# 300

# %%
df['Duration'].mean()
# Out:
# 63.84615384615385

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df[['Maxpulse']][df.Pulse==df.Pulse.min()]
# Out:
#      Maxpulse
# 93        100
# 159       120

# %%
df.index
# Out:
# RangeIndex(start=0, stop=169, step=1)

# %%
import pandas as pd
df1=pd.read_csv("Desktop/missingdata.csv",na_values=["not avaliable","n.a"])
df1
# Out:
#   tickers    eps  revenue   price      people
# 0   GOOGL  27.82       87   845.0  larry page
# 1     WMT   4.61      484    65.0         NaN
# 2    MSFT  -1.00       85    64.0   billagtes
# 3     RIL    NaN       50  1023.0   govardhan
# 4    TATA   5.60       -1     NaN    nishanth

# %%
import pandas as pd
df3=pd.read_csv("Desktop/missingdata.csv",na_values={
    'tickets':["not available","n.a"],
    'revenue':["not available","n.a",-1],
    'price':["not available","n.a"],
    'people':["not available","n.a"]
})
df3
# Out:
#   tickers            eps  revenue   price      people
# 0   GOOGL          27.82     87.0   845.0  larry page
# 1     WMT           4.61    484.0    65.0         NaN
# 2    MSFT             -1     85.0    64.0   billagtes
# 3     RIL  not avaliable     50.0  1023.0   govardhan
# 4    TATA            5.6      NaN     NaN    nishanth

# %%
df3.to_csv("Desktop/new.csv")

# %%
df4=pd.read_csv("Desktop/weather.csv")
df4
type(df4.day[0])
# Out:
# str

# %%
df4=pd.read_csv("Desktop/weather.csv",parse_dates=["day"])
type(df4.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df4
# Out:
#          day  temparature  windspeed   event
# 0 2017-01-01         32.0        6.0    rain
# 1 2017-01-04          NaN        9.0   sunny
# 2 2017-01-05         28.0        NaN    snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    rain
# 5 2017-01-08          NaN        NaN   sunny
# 6 2007-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  cloudy
# 8 2017-01-11         40.0       12.0   sunny

# %%
df4.set_index('day',inplace=True)
df4
# Out:
#             temparature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04          NaN        9.0   sunny
# 2017-01-05         28.0        NaN    snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    rain
# 2017-01-08          NaN        NaN   sunny
# 2007-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
newdf=df4.fillna(0)
newdf
# Out:
#             temparature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04          0.0        9.0   sunny
# 2017-01-05         28.0        0.0    snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    rain
# 2017-01-08          0.0        0.0   sunny
# 2007-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
newdf=df4.fillna({
    'temparature':0,
    'windspeed':0,
    'event':'no event'
})
newdf
# Out:
#             temparature  windspeed     event
# day
# 2017-01-01         32.0        6.0      rain
# 2017-01-04          0.0        9.0     sunny
# 2017-01-05         28.0        0.0      snow
# 2017-01-06          0.0        7.0  no event
# 2017-01-07         32.0        0.0      rain
# 2017-01-08          0.0        0.0     sunny
# 2007-01-09          0.0        0.0  no event
# 2017-01-10         34.0        8.0    cloudy
# 2017-01-11         40.0       12.0     sunny

# %%
#for forwarding the data abobe the nan row ffill=forwardfill
newdf=df4.fillna(method="ffill")
newdf
# Out:
#           day  temparature  windspeed   event
# 0  01-01-2017         32.0        6.0    rain
# 1  01-04-2017         32.0        9.0   sunny
# 2  01-05-2017         28.0        9.0    snow
# 3  01-06-2017         28.0        7.0    snow
# 4  01-07-2017         32.0        7.0    rain
# 5  01-08-2017         32.0        7.0   sunny
# 6  01-09-2007         32.0        7.0   sunny
# 7  01-10-2017         34.0        8.0  cloudy
# 8  01-11-2017         40.0       12.0   sunny

# %%
#using axis we can  copy the horixantally
newdf=df4.fillna(method="bfill",axis="columns")
newdf
# Out:
#           day temparature windspeed   event
# 0  01-01-2017          32         6    rain
# 1  01-04-2017           9         9   sunny
# 2  01-05-2017          28      snow    snow
# 3  01-06-2017           7         7     NaN
# 4  01-07-2017          32      rain    rain
# 5  01-08-2017       sunny     sunny   sunny
# 6  01-09-2007         NaN       NaN     NaN
# 7  01-10-2017          34         8  cloudy
# 8  01-11-2017          40        12   sunny

# %%
#using limits we can fill with a particualt limil
newdf=df4.fillna(method="ffill",limit=1)
newdf
# Out:
#           day  temparature  windspeed   event
# 0  01-01-2017         32.0        6.0    rain
# 1  01-04-2017         32.0        9.0   sunny
# 2  01-05-2017         28.0        9.0    snow
# 3  01-06-2017         28.0        7.0    snow
# 4  01-07-2017         32.0        7.0    rain
# 5  01-08-2017         32.0        NaN   sunny
# 6  01-09-2007          NaN        NaN   sunny
# 7  01-10-2017         34.0        8.0  cloudy
# 8  01-11-2017         40.0       12.0   sunny

# %%
df4
# Out:
#          day  temparature  windspeed   event
# 0 2017-01-01         32.0        6.0    rain
# 1 2017-01-04          NaN        9.0   sunny
# 2 2017-01-05         28.0        NaN    snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    rain
# 5 2017-01-08          NaN        NaN   sunny
# 6 2007-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  cloudy
# 8 2017-01-11         40.0       12.0   sunny

# %%
newdf=df4.interpolate()
print(newdf)
# Out:
#          day  temparature  windspeed   event
# 0 2017-01-01    32.000000       6.00    rain
# 1 2017-01-04    30.000000       9.00   sunny
# 2 2017-01-05    28.000000       8.00    snow
# 3 2017-01-06    30.000000       7.00     NaN
# 4 2017-01-07    32.000000       7.25    rain
# 5 2017-01-08    32.666667       7.50   sunny
# 6 2007-01-09    33.333333       7.75     NaN
# 7 2017-01-10    34.000000       8.00  cloudy
# 8 2017-01-11    40.000000      12.00   sunny

# %%
df4.set_index('day',inplace=True)
df4
# Out:
#             temparature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04          NaN        9.0   sunny
# 2017-01-05         28.0        NaN    snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    rain
# 2017-01-08          NaN        NaN   sunny
# 2007-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
##2nd,3rd date data is missing so there is some inconsisstency in data
##so use method=time for condirsering the dates
newdf=df4.interpolate(method="time")
newdf
# Out:
#             temparature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    rain
# 2017-01-04    29.000000       9.00   sunny
# 2017-01-05    28.000000       8.00    snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    rain
# 2017-01-08    32.666667       7.50   sunny
# 2007-01-09    32.000000       6.00     NaN
# 2017-01-10    34.000000       8.00  cloudy
# 2017-01-11    40.000000      12.00   sunny

# %%
#to show the only the rows wchich dont have na values
newdf=df4.dropna()
print(newdf)
# Out:
#             temparature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
#to drop the rows which have all na
newdf=df4.dropna(how="all")
newdf
# Out:
#             temparature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04          NaN        9.0   sunny
# 2017-01-05         28.0        NaN    snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    rain
# 2017-01-08          NaN        NaN   sunny
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
#if atlaset one non NA keep that value based on thresold value
#thresold values may change
newdf=df4.dropna(thresh=1)
newdf
# Out:
#             temparature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04          NaN        9.0   sunny
# 2017-01-05         28.0        NaN    snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    rain
# 2017-01-08          NaN        NaN   sunny
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
newdf=df4.dropna(thresh=2)
newdf
# Out:
#             temparature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04          NaN        9.0   sunny
# 2017-01-05         28.0        NaN    snow
# 2017-01-07         32.0        NaN    rain
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
#to get all the missing dates in the given range
dt=pd.date_range("2017-01-01","2017-01-11")
idx=pd.DatetimeIndex(dt)
newdf=df4.reindex(idx)
newdf
# Out:
#             temparature  windspeed   event
# 2017-01-01         32.0        6.0    rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   sunny
# 2017-01-05         28.0        NaN    snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    rain
# 2017-01-08          NaN        NaN   sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
import pandas as pd
import numpy as np
df5=pd.read_csv("Desktop/weatherdata.csv")
df5
# Out:
#           day  tempatrature  windspeed     event
# 0  01-01-2017            32          6      Rain
# 1  02-01-2017        -99999          7     sunny
# 2  03-01-2017            28     -99999      snow
# 3  04-01-2017        -99999          7  no event
# 4  05-01-2017            32     -99999      rain
# 5  06-01-2017            31          2     sunny
# 6  06-01-2017            34          5  no event

# %%
#to replace all the -99999 values to NANnwe can use list of values als
newdf=df5.replace(-99999,np.NAN)
newdf
# Out:
#           day  tempatrature  windspeed     event
# 0  01-01-2017          32.0        6.0      Rain
# 1  02-01-2017           NaN        7.0     sunny
# 2  03-01-2017          28.0        NaN      snow
# 3  04-01-2017           NaN        7.0  no event
# 4  05-01-2017          32.0        NaN      rain
# 5  06-01-2017          31.0        2.0     sunny
# 6  06-01-2017          34.0        5.0  no event

# %%
#to repalce values based on specific column
newdf=df5.replace({
    'temparature':-99999,
    'windspeed':-99999,
    'event':'no event'
},np.NAN)
newdf
# Out:
#           day  tempatrature  windspeed  event
# 0  01-01-2017            32        6.0   Rain
# 1  02-01-2017        -99999        7.0  sunny
# 2  03-01-2017            28        NaN   snow
# 3  04-01-2017        -99999        7.0    NaN
# 4  05-01-2017            32        NaN   rain
# 5  06-01-2017            31        2.0  sunny
# 6  06-01-2017            34        5.0    NaN

# %%
#to repalce missing data with partiular value
newdf=df5.replace({
    -99999:np.NAN,
    'no event':'sunny'
})
newdf
# Out:
#           day  tempatrature  windspeed  event
# 0  01-01-2017          32.0        6.0   Rain
# 1  02-01-2017           NaN        7.0  sunny
# 2  03-01-2017          28.0        NaN   snow
# 3  04-01-2017           NaN        7.0  sunny
# 4  05-01-2017          32.0        NaN   rain
# 5  06-01-2017          31.0        2.0  sunny
# 6  06-01-2017          34.0        5.0  sunny

# %%
df5=pd.read_csv("Desktop/weatherdata.csv")
df5
# Out:
#           day tempatrature windspeed     event
# 0  01-01-2017         32 F      6mph      Rain
# 1  02-01-2017       -99999      7mph     sunny
# 2  03-01-2017         28 C    -99999      snow
# 3  04-01-2017       -99999         7  no event
# 4  05-01-2017           32    -99999      rain
# 5  06-01-2017           31         2     sunny
# 6  06-01-2017           34         5  no event

# %%
#to remove the f,c,mph in the dataframes regex=regularexpression
newdf=df5.replace({
    'tempatrature':'[A-Za-z]',
    'windspeed':'[A-za-z]'
},'',regex=True)
newdf
# Out:
#           day tempatrature windspeed     event
# 0  01-01-2017          32          6      Rain
# 1  02-01-2017       -99999         7     sunny
# 2  03-01-2017          28     -99999      snow
# 3  04-01-2017       -99999         7  no event
# 4  05-01-2017           32    -99999      rain
# 5  06-01-2017           31         2     sunny
# 6  06-01-2017           34         5  no event

# %%
df6=pd.read_csv("Desktop/data/cityweather.csv")
df6
# Out:
#            day      city  temparature  windspeed   event
# 0   01-01-2017  new york           32          6    Rain
# 1   02-01-2017  new york           36          7   Sunny
# 2   03-01-2017  new york           28         12    Snow
# 3   04-01-2017  new york           33          7   sunny
# 4   01-01-2017    mumbai           90          5   Sunny
# 5   02-01-2017    mumbai           85         12     Fog
# 6   03-01-2017    mumbai           87         15     Fog
# 7   04-01-2017    mumbai           92          5    Rain
# 8   01-01-2017     paris           45         20   Sunny
# 9   02-01-2017     paris           50         13  cloudy
# 10  03-01-2017     paris           54          8  cloudy
# 11  04-01-2017     paris           42         10  cloudy

# %%
#what was the maiximum temp in these cities and what is the avg wind speed
#to do this use group by
g=df6.groupby('city')
g
#we will get data frame groupbyobject we will 3 different groups
#each correspnods to each city and a key with city name

# %%
#to access
for city,city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#           day    city  temparature  windspeed  event
# 4  01-01-2017  mumbai           90          5  Sunny
# 5  02-01-2017  mumbai           85         12    Fog
# 6  03-01-2017  mumbai           87         15    Fog
# 7  04-01-2017  mumbai           92          5   Rain
# new york
#           day      city  temparature  windspeed  event
# 0  01-01-2017  new york           32          6   Rain
# 1  02-01-2017  new york           36          7  Sunny
# 2  03-01-2017  new york           28         12   Snow
# 3  04-01-2017  new york           33          7  sunny
# paris
#            day   city  temparature  windspeed   event
# 8   01-01-2017  paris           45         20   Sunny
# 9   02-01-2017  paris           50         13  cloudy
# 10  03-01-2017  paris           54          8  cloudy
# 11  04-01-2017  paris           42         10  cloudy

# %%
g.get_group('mumbai')
# Out:
#           day    city  temparature  windspeed  event
# 4  01-01-2017  mumbai           90          5  Sunny
# 5  02-01-2017  mumbai           85         12    Fog
# 6  03-01-2017  mumbai           87         15    Fog
# 7  04-01-2017  mumbai           92          5   Rain

# %%
g.max()
# Out:
#                  day  temparature  windspeed   event
# city
# mumbai    04-01-2017           92         15   Sunny
# new york  04-01-2017           36         12   sunny
# paris     04-01-2017           54         20  cloudy

# %%
g.mean()
# Out:
#           temparature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
g.describe()
# Out:
#          temparature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
# %matplotlib inline
g.plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
#joining dataframes
india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df7=pd.concat([india_weather,us_weather])
df7
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
#still newyork index is zero
#to get index continuosulsy 
df7=pd.concat([india_weather,us_weather],ignore_index=True)
df7
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
#to get a table with index
df7=pd.concat([india_weather,us_weather],keys=["india","us"])
df7
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df7.loc["us"]
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
#to append the datafraome as colums
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["delhi","mumbai","banglore"],
    "windspeed": [7,12,19],
})
windspeed_df
# Out:
#        city  windspeed
# 0     delhi          7
# 1    mumbai         12
# 2  banglore         19

# %%
#to concate the 2 data frames vertically use axis=1 by defalult axix is 0
df=pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#        city  temperature      city  windspeed
# 0    mumbai           32     delhi          7
# 1     delhi           45    mumbai         12
# 2  banglore           30  banglore         19

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({    #use indec 
    "city": ["delhi","mumbai"],
    "windspeed": [7,12],
}, index=[1,0])
windspeed_df
# Out:
#      city  windspeed
# 1   delhi          7
# 0  mumbai         12

# %%
df=pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32  mumbai       12.0
# 1     delhi           45   delhi        7.0
# 2  banglore           30     NaN        NaN

# %%
#to append series of data
s=pd.Series(["humid","dry","rain"],name="event")
s
# Out:
# 0    humid
# 1      dry
# 2     rain
# Name: event, dtype: object

# %%
df=pd.concat([temperature_df,s],axis=1)
df
# Out:
#        city  temperature  event
# 0    mumbai           32  humid
# 1     delhi           45    dry
# 2  banglore           30   rain

# %%
#merging dataframes
import pandas as pd
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
df2=pd.merge(df1,df2,on="city")  #if we use how="outer" then it will uninoin of two dataframes
df2
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df6
# Out:
#            day      city  temparature  windspeed   event
# 0   01-01-2017  new york           32          6    Rain
# 1   02-01-2017  new york           36          7   Sunny
# 2   03-01-2017  new york           28         12    Snow
# 3   04-01-2017  new york           33          7   sunny
# 4   01-01-2017    mumbai           90          5   Sunny
# 5   02-01-2017    mumbai           85         12     Fog
# 6   03-01-2017    mumbai           87         15     Fog
# 7   04-01-2017    mumbai           92          5    Rain
# 8   01-01-2017     paris           45         20   Sunny
# 9   02-01-2017     paris           50         13  cloudy
# 10  03-01-2017     paris           54          8  cloudy
# 11  04-01-2017     paris           42         10  cloudy

# %%
#for data analytics purpose we need to change the table 
#like x axis is date and y-axis is temparature...
df6.pivot(index="day",columns="city")
# Out:
#            temparature                windspeed                 event  \
# city            mumbai new york paris    mumbai new york paris mumbai
# day
# 01-01-2017          90       32    45         5        6    20  Sunny
# 02-01-2017          85       36    50        12        7    13    Fog
# 03-01-2017          87       28    54        15       12     8    Fog
# 04-01-2017          92       33    42         5        7    10   Rain
#
#
# city       new york   paris
# day
# 01-01-2017     Rain   Sunny
# 02-01-2017    Sunny  cloudy
# 03-01-2017     Snow  cloudy
# 04-01-2017    sunny  cloudy

# %%
df6.pivot(index="day",columns="city",values="temparature")
##we can give extra arguemnets also
# Out:
# city        mumbai  new york  paris
# day
# 01-01-2017      90        32     45
# 02-01-2017      85        36     50
# 03-01-2017      87        28     54
# 04-01-2017      92        33     42

# %%
##pivot table is used to summarize and aggreagate data insidde data frame
df7=pd.read_csv("Desktop/data/weather2.csv")
df7
# Out:
#          date      city  temparature  humidity
# 0  01-05-2017  new york           65        56
# 1  01-05-2017  new york           61        54
# 2  02-05-2017  new york           70        60
# 3  02-05-2017  new york           72        62
# 4  01-05-2017    mumbai           75        80
# 5  01-05-2017    mumbai           76        83
# 6  02-05-2017    mumbai           82        85
# 7  02-05-2017    mumbai           80        26

# %%
##here for same date we ar ehaving 2 different values like mrnga nd evng so we will take avg
df7.pivot_table(index="city",columns="date")
# Out:
#            humidity            temparature
# date     01-05-2017 02-05-2017  01-05-2017 02-05-2017
# city
# mumbai         81.5       55.5        75.5       81.0
# new york       55.0       61.0        63.0       71.0

# %%
df7.pivot_table(index="city",columns="date",aggfunc="sum")
# Out:
#            humidity            temparature
# date     01-05-2017 02-05-2017  01-05-2017 02-05-2017
# city
# mumbai          163        111         151        162
# new york        110        122         126        142

# %%
df7.pivot_table(index="city",columns="date",aggfunc="count")
# Out:
#            humidity            temparature
# date     01-05-2017 02-05-2017  01-05-2017 02-05-2017
# city
# mumbai            2          2           2          2
# new york          2          2           2          2

# %%
#mean is default
df7.pivot_table(index="city",columns="date",aggfunc="mean")
# Out:
#            humidity            temparature
# date     01-05-2017 02-05-2017  01-05-2017 02-05-2017
# city
# mumbai         81.5       55.5        75.5       81.0
# new york       55.0       61.0        63.0       71.0

# %%
df7.pivot_table(index="city",columns="date",margins=True)
#All columns is added like avg
# Out:
#            humidity                   temparature
# date     01-05-2017 02-05-2017    All  01-05-2017 02-05-2017     All
# city
# mumbai        81.50      55.50  68.50       75.50       81.0  78.250
# new york      55.00      61.00  58.00       63.00       71.0  67.000
# All           68.25      58.25  63.25       69.25       76.0  72.625

# %%
###Reshape the dataframe
df8=pd.read_csv("Desktop/data/reshape.csv")
df8
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77       3
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
df8=pd.melt(df8,id_vars=["day"])
df8
# Out:
#           day variable  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wednesday  chicago     28
# 3    Thursday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     20
# 6      Sunday  chicago     25
# 7      Monday  chennai     75
# 8     Tuesday  chennai     77
# 9   Wednesday  chennai     75
# 10   Thursday  chennai     82
# 11     Friday  chennai     83
# 12   Saturday  chennai     81
# 13     Sunday  chennai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin      3
# 16  Wednesday   berlin     45
# 17   Thursday   berlin     38
# 18     Friday   berlin     30
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47

# %%
df8[df8["variable"]=="chicago"]
# Out:
#          day variable  value
# 0     Monday  chicago     32
# 1    Tuesday  chicago     30
# 2  Wednesday  chicago     28
# 3   Thursday  chicago     22
# 4     Friday  chicago     30
# 5   Saturday  chicago     20
# 6     Sunday  chicago     25

# %%
df9=pd.melt(df8,id_vars=["day"],var_name="city",value_name="temparatue")
df9
# Out:
#           day     city  temparatue
# 0      Monday  chicago          32
# 1     Tuesday  chicago          30
# 2   Wednesday  chicago          28
# 3    Thursday  chicago          22
# 4      Friday  chicago          30
# 5    Saturday  chicago          20
# 6      Sunday  chicago          25
# 7      Monday  chennai          75
# 8     Tuesday  chennai          77
# 9   Wednesday  chennai          75
# 10   Thursday  chennai          82
# 11     Friday  chennai          83
# 12   Saturday  chennai          81
# 13     Sunday  chennai          77
# 14     Monday   berlin          41
# 15    Tuesday   berlin           3
# 16  Wednesday   berlin          45
# 17   Thursday   berlin          38
# 18     Friday   berlin          30
# 19   Saturday   berlin          45
# 20     Sunday   berlin          47
